# %%
# supervised - output already there,data is labeled
# unsupervised - no labels,no output,useful for hidden patterns

# claaification - it is  categorical,like ture or False
# regression - it is continuous , like print

# features (x) - input calumns like age,salary
# target (y) - output variable,like loan ststus

# rules:
# ml learning patterns from x
# with that ml predicts y

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c9a416b-480e-46a2-a07f-aa2a3122943f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c9a416b-480e-46a2-a07f-aa2a3122943f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('loan_approval_dataset.csv')
print(df.columns)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.columns = df.columns.str.strip() # Ensure column names are clean

plt.figure(figsize=(8, 6))
sns.countplot(x='loan_status', data=df, palette='viridis')
plt.title('Distribution of Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-2017604586.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='loan_status', data=df, palette='viridis')

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# ...

# %%
df.tail()
# Out:
#       loan_id  no_of_dependents      education self_employed  income_annum  \
# 4264     4265                 5       Graduate           Yes       1000000
# 4265     4266                 0   Not Graduate           Yes       3300000
# 4266     4267                 2   Not Graduate            No       6500000
# 4267     4268                 1   Not Graduate            No       4100000
# 4268     4269                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 4264      2300000         12          317                   2800000
# 4265     11300000         20          559                   4200000
# 4266     23900000         18          457                   1200000
# 4267     12800000          8          780                   8200000
# 4268     29700000         10          607                  17800000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value  \
# ...

# %%
df.size
# Out:
# 55497

# %%
df.describe()
# Out:
#            loan_id  no_of_dependents  income_annum   loan_amount    loan_term  \
# count  4269.000000       4269.000000  4.269000e+03  4.269000e+03  4269.000000
# mean   2135.000000          2.498712  5.059124e+06  1.513345e+07    10.900445
# std    1232.498479          1.695910  2.806840e+06  9.043363e+06     5.709187
# min       1.000000          0.000000  2.000000e+05  3.000000e+05     2.000000
# 25%    1068.000000          1.000000  2.700000e+06  7.700000e+06     6.000000
# 50%    2135.000000          3.000000  5.100000e+06  1.450000e+07    10.000000
# 75%    3202.000000          4.000000  7.500000e+06  2.150000e+07    16.000000
# max    4269.000000          5.000000  9.900000e+06  3.950000e+07    20.000000
#
#        cibil_score  residential_assets_value  commercial_assets_value  \
# count  4269.000000              4.269000e+03             4.269000e+03
# mean    599.936051              7.472617e+06             4.973155e+06
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
x = df.drop('loan_status', axis=1)
y = df['loan_status']
print(x.columns)

#in this
#y is what we want to predicts
#x is the data after we remove that target to avoid data leakage
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value'],
#       dtype='object')

# %%
# checking the missing values

df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
# train and tset split

from sklearn.model_selection import train_test_split
# scikit - learn , it is one of the most popular python libraries for ML
# this train and test split is to avoid the data leakage

x_train, x_test, y_train, y_test,= train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
    )

# x_train - input data for training
# x_test - input data for testing
# y_traing - correct answer for training
# y_test - correct answer for testing

# x_train + y_train - model learned
# x_test + y_test - model is evaluated

# stratify - like it make sure all classes are
# evenly represened in train and test split
# class total -
# pass - 90 fail - 10

# train and test split
# 90 and 10 for train and test for test, then we will implement stratify

# %%
x_train.shape
# Out:
# (3415, 12)

# %%
x_test.shape

# 4269 total row before splitting
# 854 is test x after splitting
# 845/4269 = 0.20
# Out:
# (854, 12)

# %%
y_train.value_counts(normalize=True)
# 62 38
# Out:
# loan_status
# Approved    0.622255
# Rejected    0.377745
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# loan_status
# Approved    0.62178
# Rejected    0.37822
# Name: proportion, dtype: float64

# %%
# the topics we did are:
# model framing
# target indentified
# feature-target separation
# missing values check
# train test split using random state and stratify
# verified the split:
# x train shape , x test shape
# y train shape , y test shape

# %%
x_train.dtypes
# Out:
# loan_id                      int64
# no_of_dependents             int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term                    int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_asset_value             int64
# dtype: object

# %%
x_train = x_train.drop('loan_id',axis=1)
x_test = x_test.drop('loan_id',axis=1)
#loan id is just an identifier which has no meaning , if we k
#it, the model may learn noise
#removing unnecessary columns from the model train and test

# %%
x_train.dtypes
# Out:
# no_of_dependents             int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term                    int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_asset_value             int64
# dtype: object

# %%
# encoding the model x train and x test
# one hot encode categorial features

from sklearn.preprocessing import OneHotEncoder

categorical_cols = ["education","self_employed",]
ohe = OneHotEncoder(drop='first',sparse_output=False)
x_train_cat = ohe.fit_transform(x_train[categorical_cols])
x_test_cat = ohe.transform(x_test[categorical_cols])

# the drop is to emove the redundat columns to avoid dummy
# variable trap
# spares in default would store them as a numpy array ,
# if false itll give the encoded data as a normal tabel of
# numbers instead compressing it

# %%
x_train_cat.shape
# Out:
# (3415, 2)

# %%
x_test_cat.shape
# Out:
# (854, 2)

# %%
np.unique(x_train_cat)
# Out:
# array([0., 1.])

# %%
np.unique(x_test_cat)
# Out:
# array([0., 1.])

# %%
ohe.get_feature_names_out(categorical_cols)
# Out:
# array(['education_ Not Graduate', 'self_employed_ Yes'], dtype=object)

# %%
ohe.categories_
# Out:
# [array([' Graduate', ' Not Graduate'], dtype=object),
#  array([' No', ' Yes'], dtype=object)]

# %%
# scaling numeric features

from sklearn.preprocessing import StandardScaler
numeric_cols = x_train.drop(columns=categorical_cols).columns
scales = StandardScaler()
x_train_num = scales.fit_transform(x_train[numeric_cols])
x_test_num = scales.fit_transform(x_test[numeric_cols])

# %%
x_train_num_df = pd.DataFrame(
    x_train_num,
    columns=numeric_cols,
    index=x_train.index
)

x_train_num_df.head()
# x_test_num_df = pd.DataFrame(
#     x_test_num,
#     columns=numeric_cols,
#     index=xtest.index
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 1224         -1.456965      1.700955     0.983585   0.549181    -0.806352
# 478           0.305326     -0.514765    -0.717129  -0.500709     1.110842
# 3065         -0.282104     -1.086564    -1.228455   0.549181    -0.557291
# 326          -0.282104     -0.407553    -0.417003   0.199218    -0.476201
# 2991          0.305326     -0.979352    -0.728245   0.199218    -0.238724
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 1224                 -0.995573                 1.942808             0.659076
# 478                  -0.312884                 0.216625            -0.582560
# 3065                 -0.390463                -0.796070            -1.066029
# 326                  -0.669744                -1.141306            -0.516632
# 2991                 -0.592166                -0.819085            -0.978125
#
#       bank_asset_value
# 1224          0.696034
# ...

# %%
print(df['loan_status'].value_counts())
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64
